# %%
import selenium
import time
import os
import time
import pandas as pd
import io

# %%
from selenium import webdriver
from selenium.webdriver.support.ui import Select

# %%
driverPath=r"C:\Users\merit\Desktop\Notes\Python\chromedriver_win32\chromedriver.exe"
driver=webdriver.Chrome(executable_path=driverPath)
driver.get("https://www.cricbuzz.com/cricket-stats/icc-rankings/men/batting")
driver.maximize_window()

writer = pd.ExcelWriter('Batting.xlsx',engine='xlsxwriter')
Batting=driver.find_element_by_xpath("//a[@id='batsmen-tab']").click()
time.sleep(1)

driver.find_element_by_xpath("//a[@id='batsmen-tests-tab']").click()
Test = driver.find_elements_by_xpath("//a[@id='batsmen-tests-tab']//following::div[contains(@class,'cb-col cb-col-100 text-bold cb-font-14 cb-rank-hdr cb-bg-grey text-center')]//following::div[contains(@class,'cb-col cb-col-100 cb-font-14 cb-lst-itm text-center')]")

ListOfTest= []
for i in Test:
    if i.text != '':
        ListOfTest.append(i.text.split("\n"))
print("Test: ", ListOfTest)


driver.find_element_by_xpath("//a[@id='batsmen-odis-tab']").click()
ODI = driver.find_elements_by_xpath("//a[@id='batsmen-odis-tab']//following::div[contains(@class,'cb-col cb-col-100 text-bold cb-font-14 cb-rank-hdr cb-bg-grey text-center')]//following::div[contains(@class,'cb-col cb-col-100 cb-font-14 cb-lst-itm text-center')]")

ListOfODI= []
for o in ODI:
    if o.text != '':
        ListOfODI.append(o.text.split("\n"))
print("ODI: ", ListOfODI)


driver.find_element_by_xpath("//a[@id='batsmen-t20s-tab']").click()
T20 = driver.find_elements_by_xpath("//a[@id='batsmen-t20s-tab']//following::div[contains(@class,'cb-col cb-col-100 text-bold cb-font-14 cb-rank-hdr cb-bg-grey text-center')]//following::div[contains(@class,'cb-col cb-col-100 cb-font-14 cb-lst-itm text-center')]")

ListOfT20= []
for t in T20:
    if t.text != '':
        ListOfT20.append(t.text.split("\n"))
print("T20: ", ListOfT20)


df1 = pd.DataFrame(ListOfTest,columns=["Position","Ranking","Player","Country","Rating"])
df1.to_excel(writer,sheet_name='Test',index=False)
print(df)

df2 = pd.DataFrame(ListOfODI,columns=["Position","Ranking","Player","Country","Rating"])
df2.to_excel(writer,sheet_name='ODI',index=False)
print(df1)

df3 = pd.DataFrame(ListOfT20,columns=["Position","Ranking","Player","Country","Rating"])
df3.to_excel(writer,sheet_name='T20',index=False)
print(df2)

writer.save()


# ===============================================================================================
# ===============================================================================================
# ===============================================================================================


Bowling = driver.find_element_by_xpath("//a[@id='bowlers-tab']").click()
time.sleep(1)

driver.find_element_by_xpath("//a[@id='bowlers-tests-tab']").click()
BTest = driver.find_elements_by_xpath("//a[@id='bowlers-tests-tab']//following::div[contains(@class,'cb-col cb-col-100 text-bold cb-font-14 cb-rank-hdr cb-bg-grey text-center')]//following::div[contains(@class,'cb-col cb-col-100 cb-font-14 cb-lst-itm text-center')]")

ListOfBTest= []
for bi in BTest:
    if bi.text != '':
        ListOfBTest.append(bi.text.split("\n"))
print("Test: ", ListOfBTest)

driver.find_element_by_xpath("//a[@id='bowlers-odis-tab']").click()
BODI = driver.find_elements_by_xpath("//a[@id='bowlers-odis-tab']//following::div[contains(@class,'cb-col cb-col-100 text-bold cb-font-14 cb-rank-hdr cb-bg-grey text-center')]//following::div[contains(@class,'cb-col cb-col-100 cb-font-14 cb-lst-itm text-center')]")

ListOfBODI= []
for bo in BODI:
    if bo.text != '':
        ListOfBODI.append(bo.text.split("\n"))
print("ODI: ", ListOfBODI)


driver.find_element_by_xpath("//a[@id='bowlers-t20s-tab']").click()
BT20 = driver.find_elements_by_xpath("//a[@id='bowlers-t20s-tab']//following::div[contains(@class,'cb-col cb-col-100 text-bold cb-font-14 cb-rank-hdr cb-bg-grey text-center')]//following::div[contains(@class,'cb-col cb-col-100 cb-font-14 cb-lst-itm text-center')]")

ListOfBT20= []
for bt in BT20:
    if bt.text != '':
        ListOfBT20.append(bt.text.split("\n"))
print("T20: ", ListOfBT20)

writer = pd.ExcelWriter('Bowling.xlsx',engine='xlsxwriter')

df4 = pd.DataFrame(ListOfBTest,columns=["Position","Ranking","Player","Country","Rating"])
df4.to_excel(writer,sheet_name='Test',index=False)
print(df4)

df5 = pd.DataFrame(ListOfBODI,columns=["Position","Ranking","Player","Country","Rating"])
df5.to_excel(writer,sheet_name='ODI',index=False)
print(df5)

df6 = pd.DataFrame(ListOfBT20,columns=["Position","Ranking","Player","Country","Rating"])
df6.to_excel(writer,sheet_name='T20',index=False)
print(df6)

writer.save()


# ===============================================================================================
# ===============================================================================================
# ===============================================================================================


All_Rounder = driver.find_element_by_xpath("//a[@id='all-rounders-tab']").click()
time.sleep(1)

driver.find_element_by_xpath("//a[@id='allrounders-tests-tab']").click()
ATest = driver.find_elements_by_xpath("//a[@id='allrounders-tests-tab']//following::div[contains(@class,'cb-col cb-col-100 text-bold cb-font-14 cb-rank-hdr cb-bg-grey text-center')]//following::div[contains(@class,'cb-col cb-col-100 cb-font-14 cb-lst-itm text-center')]")

ListOfATest= []
for ai in ATest:
    if ai.text != '':
        ListOfATest.append(ai.text.split("\n"))
print("Test: ", ListOfATest)

driver.find_element_by_xpath("//a[@id='allrounders-odis-tab']").click()
AODI = driver.find_elements_by_xpath("//a[@id='allrounders-odis-tab']//following::div[contains(@class,'cb-col cb-col-100 text-bold cb-font-14 cb-rank-hdr cb-bg-grey text-center')]//following::div[contains(@class,'cb-col cb-col-100 cb-font-14 cb-lst-itm text-center')]")

ListOfAODI= []
for ao in AODI:
    if ao.text != '':
        ListOfAODI.append(ao.text.split("\n"))
print("ODI: ", ListOfAODI)


driver.find_element_by_xpath("//a[@id='allrounders-t20s-tab']").click()
AT20 = driver.find_elements_by_xpath("//a[@id='allrounders-t20s-tab']//following::div[contains(@class,'cb-col cb-col-100 text-bold cb-font-14 cb-rank-hdr cb-bg-grey text-center')]//following::div[contains(@class,'cb-col cb-col-100 cb-font-14 cb-lst-itm text-center')]")

ListOfAT20= []
for at in AT20:
    if at.text != '':
        ListOfAT20.append(at.text.split("\n"))
print("T20: ", ListOfAT20)

writer = pd.ExcelWriter('All_Rounder.xlsx',engine='xlsxwriter')

df7 = pd.DataFrame(ListOfATest,columns=["Position","Ranking","Player","Country","Rating"])
df7.to_excel(writer,sheet_name='Test',index=False)
print(df7)

df8 = pd.DataFrame(ListOfAODI,columns=["Position","Ranking","Player","Country","Rating"])
df8.to_excel(writer,sheet_name='ODI',index=False)
print(df8)

df9 = pd.DataFrame(ListOfAT20,columns=["Position","Ranking","Player","Country","Rating"])
df9.to_excel(writer,sheet_name='T20',index=False)
print(df9)

writer.save()

# ===============================================================================================
# ===============================================================================================
# ===============================================================================================


Teams = driver.find_element_by_xpath("//a[@id='teams-tab']").click()
time.sleep(1)

driver.find_element_by_xpath("//a[@id='teams-tests-tab']").click()
TTest = driver.find_elements_by_xpath("//a[@id='teams-tests-tab']//following::div[contains(@class,'cb-bg-grey text-center')]//following::div[contains(@class,'cb-brdr-thin-btm text-center')]")

ListOfTTest= []
for ti in TTest:
    if ti.text != '':
        ListOfTTest.append(ti.text.split("\n"))
print("Test: ", ListOfTTest)

driver.find_element_by_xpath("//a[@id='teams-odis-tab']").click()
TODI = driver.find_elements_by_xpath("//a[@id='teams-odis-tab']//following::div[contains(@class,'cb-bg-grey text-center')]//following::div[contains(@class,'cb-brdr-thin-btm text-center')]")

ListOfTODI= []
for to in TODI:
    if to.text != '':
        ListOfTODI.append(to.text.split("\n"))
print("ODI: ", ListOfTODI)


driver.find_element_by_xpath("//a[@id='teams-t20s-tab']").click()
TT20 = driver.find_elements_by_xpath("//a[@id='teams-t20s-tab']//following::div[contains(@class,'cb-bg-grey text-center')]//following::div[contains(@class,'cb-brdr-thin-btm text-center')]")

ListOfTT20= []
for tt in TT20:
    if tt.text != '':
        ListOfTT20.append(tt.text.split("\n"))
print("T20: ", ListOfTT20)

writer = pd.ExcelWriter('Teams.xlsx',engine='xlsxwriter')

df10 = pd.DataFrame(ListOfTTest,columns=["Position","Team","Rating","Points"])
df10.to_excel(writer,sheet_name='Test',index=False)
print(df10)

df11 = pd.DataFrame(ListOfTODI,columns=["Position","Team","Rating","Points"])
df11.to_excel(writer,sheet_name='ODI',index=False)
print(df11)

df12 = pd.DataFrame(ListOfTT20,columns=["Position","Team","Rating","Points"])
df12.to_excel(writer,sheet_name='T20',index=False)
print(df12)

writer.save()

driver.back()
driver.close()
# Out:
# Test:  [['1', '    1', 'Joe Root', 'ENGLAND', '903'], ['2', '    1', 'Kane Williamson', 'NEW ZEALAND', '901'], ['3', '    –', 'Steven Smith', 'AUSTRALIA', '891'], ['4', '    –', 'Marnus Labuschagne', 'AUSTRALIA', '878'], ['5', '    1', 'Rohit Sharma', 'INDIA', '813'], ['6', '    1', 'Virat Kohli', 'INDIA', '783'], ['7', '    –', 'Babar Azam', 'PAKISTAN', '749'], ['8', '    1', 'David Warner', 'AUSTRALIA', '724'], ['9', '    1', 'Quinton de Kock', 'SOUTH AFRICA', '717'], ['10', '    1', 'Henry Nicholls', 'NEW ZEALAND', '714'], ['11', '    1', 'Dimuth Karunaratne', 'SRI LANKA', '712'], ['12', '    1', 'Ross Taylor', 'NEW ZEALAND', '693'], ['13', '    5', 'Rishabh Pant', 'INDIA', '690'], ['14', '    –', 'Tom Latham', 'NEW ZEALAND', '677'], ['15', '    3', 'Cheteshwar Pujara', 'INDIA', '673'], ['16', '    –', 'Ben Stokes', 'ENGLAND', '664'], ['17', '    –', 'Dean Elgar', 'SOUTH AFRICA', '661'], ['18', '    1', 'Mohammad Rizwan', 'PAKISTAN', '651'], ['19', '    1', 'Aiden Markram', 'SOUTH AFRICA', '651'], ['20', '    1', 'Fawad Alam', 'PAKISTAN', '640'], ['21', '    1', 'Azhar Ali', 'PAKISTAN', '636'], ['22', '    7', 'Ajinkya Rahane', 'INDIA', '630'], ['23', '    –', 'Mushfiqur Rahim', 'BANGLADESH', '626'], ['24', '    5', 'Rory Burns', 'ENGLAND', '619'], ['25', '    1', 'Travis Head', 'AUSTRALIA', '618'], ['26', '    1', 'Angelo Mathews', 'SRI LANKA', '618'], ['27', '    1', 'Tamim Iqbal', 'BANGLADESH', '605'], ['28', '    1', 'Sean Williams', 'ZIMBABWE', '603'], ['29', '    1', 'Brendan Taylor', 'ZIMBABWE', '603'], ['30', '    –', 'Mominul Haque', 'BANGLADESH', '596'], ['31', '    –', 'Niroshan Dickwella', 'SRI LANKA', '589'], ['32', '    –', 'Dhananjaya de Silva', 'SRI LANKA', '588'], ['33', '    2', 'Jermaine Blackwood', 'WEST INDIES', '576'], ['34', '    1', 'Mayank Agarwal', 'INDIA', '571'], ['35', '    1', 'Faf du Plessis', 'SOUTH AFRICA', '570'], ['36', '    1', 'Jason Holder', 'WEST INDIES', '567'], ['37', '    3', 'Jos Buttler', 'ENGLAND', '564'], ['38', '    –', 'Asad Shafiq', 'PAKISTAN', '561'], ['39', '    2', 'Tim Paine', 'AUSTRALIA', '555'], ['40', '    2', 'Shakib Al Hasan', 'BANGLADESH', '553'], ['41', '    2', 'Colin de Grandhomme', 'NEW ZEALAND', '549'], ['42', '    2', 'Devon Conway', 'NEW ZEALAND', '547'], ['43', '    2', 'Kraigg Brathwaite', 'WEST INDIES', '543'], ['44', '    2', 'Rassie van der Dussen', 'SOUTH AFRICA', '542'], ['45', '    2', 'Mahmudullah', 'BANGLADESH', '540'], ['46', '    7', 'KL Rahul', 'INDIA', '539'], ['47', '    1', 'Abid Ali', 'PAKISTAN', '532'], ['48', '    8', 'Ravindra Jadeja', 'INDIA', '529'], ['49', '    8', 'Ollie Pope', 'ENGLAND', '528'], ['50', '    1', 'Dinesh Chandimal', 'SRI LANKA', '526'], ['51', '    1', 'Sikandar Raza', 'ZIMBABWE', '523'], ['52', '    1', 'Craig Ervine', 'ZIMBABWE', '522'], ['53', '    1', 'Tom Blundell', 'NEW ZEALAND', '519'], ['54', '    1', 'Temba Bavuma', 'SOUTH AFRICA', '518'], ['55', '    1', 'Faheem Ashraf', 'PAKISTAN', '517'], ['56', '    1', 'Kusal Mendis', 'SRI LANKA', '514'], ['57', '    1', 'Liton Das', 'BANGLADESH', '509'], ['58', '    –', 'Matthew Wade', 'AUSTRALIA', '501'], ['59', '    –', 'Oshada Fernando', 'SRI LANKA', '499'], ['60', '    –', 'Lahiru Thirimanne', 'SRI LANKA', '498'], ['61', '    –', 'Joe Burns', 'AUSTRALIA', '497'], ['62', '    –', 'Shan Masood', 'PAKISTAN', '495'], ['63', '    –', 'Asghar Afghan', 'AFGHANISTAN', '487'], ['64', '    –', 'Ibrahim Zadran', 'AFGHANISTAN', '486'], ['65', '    –', 'Kusal Perera', 'SRI LANKA', '485'], ['66', '    3', 'Shane Dowrich', 'WEST INDIES', '476'], ['67', '    1', 'Dominic Sibley', 'ENGLAND', '473'], ['68', '    –', 'Washington Sundar', 'INDIA', '470'], ['69', '    2', 'Hanuma Vihari', 'INDIA', '470'], ['70', '    2', 'Jonny Bairstow', 'ENGLAND', '461'], ['71', '    1', 'Joe Denly', 'ENGLAND', '461'], ['72', '    1', 'Shubman Gill', 'INDIA', '459'], ['73', '    –', 'Nkrumah Bonner', 'WEST INDIES', '455'], ['74', '    –', 'Roston Chase', 'WEST INDIES', '434'], ['75', '    1', 'Kyle Jami ...
# ODI:  [['1', '    –', 'Babar Azam', 'PAKISTAN', '873'], ['2', '    –', 'Virat Kohli', 'INDIA', '844'], ['3', '    –', 'Rohit Sharma', 'INDIA', '813'], ['4', '    –', 'Ross Taylor', 'NEW ZEALAND', '801'], ['5', '    –', 'Aaron Finch', 'AUSTRALIA', '779'], ['6', '    –', 'Jonny Bairstow', 'ENGLAND', '775'], ['7', '    –', 'David Warner', 'AUSTRALIA', '762'], ['8', '    1', 'Shai Hope', 'WEST INDIES', '758'], ['9', '    1', 'Kane Williamson', 'NEW ZEALAND', '754'], ['10', '    2', 'Quinton de Kock', 'SOUTH AFRICA', '747'], ['11', '    –', 'Fakhar Zaman', 'PAKISTAN', '741'], ['12', '    –', 'Joe Root', 'ENGLAND', '740'], ['13', '    –', 'Mushfiqur Rahim', 'BANGLADESH', '723'], ['14', '    –', 'Imam-ul-Haq', 'PAKISTAN', '717'], ['15', '    –', 'Martin Guptill', 'NEW ZEALAND', '707'], ['16', '    –', 'Shikhar Dhawan', 'INDIA', '704'], ['17', '    –', 'Steven Smith', 'AUSTRALIA', '696'], ['18', '    –', 'Jason Roy', 'ENGLAND', '687'], ['19', '    –', 'Rassie van der Dussen', 'SOUTH AFRICA', '674'], ['20', '    –', 'Glenn Maxwell', 'AUSTRALIA', '674'], ['21', '    –', 'Tamim Iqbal', 'BANGLADESH', '670'], ['22', '    –', 'Alex Carey', 'AUSTRALIA', '669'], ['23', '    –', 'Paul Stirling', 'IRELAND', '658'], ['24', '    –', 'Ben Stokes', 'ENGLAND', '651'], ['25', '    –', 'Eoin Morgan', 'ENGLAND', '650'], ['26', '    –', 'Shakib Al Hasan', 'BANGLADESH', '641'], ['27', '    –', 'KL Rahul', 'INDIA', '636'], ['28', '    1', 'Tom Latham', 'NEW ZEALAND', '624'], ['29', '    1', 'David Miller', 'SOUTH AFRICA', '622'], ['30', '    –', 'Nicholas Pooran', 'WEST INDIES', '615'], ['31', '    –', 'Jos Buttler', 'ENGLAND', '608'], ['32', '    –', 'Shimron Hetmyer', 'WEST INDIES', '607'], ['33', '    –', 'Haris Sohail', 'PAKISTAN', '594'], ['34', '    31', 'Janneman Malan', 'SOUTH AFRICA', '589'], ['35', '    1', 'Henry Nicholls', 'NEW ZEALAND', '581'], ['36', '    1', 'Aqib Ilyas', 'OMAN', '578'], ['37', '    –', 'Kyle Coetzer', 'SCOTLAND', '573'], ['38', '    1', 'Mahmudullah', 'BANGLADESH', '571'], ['39', '    1', 'Brendan Taylor', 'ZIMBABWE', '569'], ['40', '    12', 'Avishka Fernando', 'SRI LANKA', '568'], ['41', '    5', 'Andrew Balbirnie', 'IRELAND', '568'], ['42', '    1', 'Rahmat Shah', 'AFGHANISTAN', '559'], ['43', '    1', 'Evin Lewis', 'WEST INDIES', '558'], ['44', '    1', 'Liton Das', 'BANGLADESH', '558'], ['45', '    –', 'Kedar Jadhav', 'INDIA', '552'], ['46', '    6', 'Kusal Perera', 'SRI LANKA', '551'], ['47', '    –', 'Hardik Pandya', 'INDIA', '548'], ['48', '    4', 'Sean Williams', 'ZIMBABWE', '545'], ['49', '    1', 'Sikandar Raza', 'ZIMBABWE', '542'], ['50', '    4', 'Angelo Mathews', 'SRI LANKA', '542'], ['51', '    2', 'Danushka Gunathilaka', 'SRI LANKA', '530'], ['52', '    1', 'Imad Wasim', 'PAKISTAN', '525'], ['53', '    –', 'Soumya Sarkar', 'BANGLADESH', '521'], ['54', '    4', 'Kusal Mendis', 'SRI LANKA', '518'], ['55', '    1', 'Marcus Stoinis', 'AUSTRALIA', '517'], ['56', '    1', 'Calum MacLeod', 'SCOTLAND', '508'], ['57', '    1', 'Colin de Grandhomme', 'NEW ZEALAND', '507'], ['58', '    1', 'Najibullah Zadran', 'AFGHANISTAN', '506'], ['59', '    1', 'Sarfaraz Ahmed', 'PAKISTAN', '504'], ['60', '    –', 'Hashmatullah Shahidi', 'AFGHANISTAN', '498'], ['61', '    –', 'Marnus Labuschagne', 'AUSTRALIA', '498'], ['62', '    –', 'James Neesham', 'NEW ZEALAND', '495'], ['63', '    4', 'Niroshan Dickwella', 'SRI LANKA', '495'], ['64', '    1', 'Mohammad Nabi', 'AFGHANISTAN', '494'], ['65', '    1', 'Mitchell Marsh', 'AUSTRALIA', '489'], ['67', '    3', 'William Porterfield', 'IRELAND', '484'], ['68', '    2', 'Asghar Afghan', 'AFGHANISTAN', '479'], ['69', '    2', 'Richie Berrington', 'SCOTLAND', '479'], ['70', '    5', 'Aiden Markram', 'SOUTH AFRICA', '478'], ['71', '    10', 'Harry Tector', 'IRELAND', '477'], ['72', '    5', 'Heinrich Klaasen', 'SOUTH AFRICA', '476'], ['73', '    –', 'Craig Ervine', 'ZIMBABWE', '476'], ['74', '    3', 'Dhananjaya de Silva', 'SRI LANKA', '473'], ['75', '    7', 'Shreyas Iyer', 'INDIA', '472'] ...
# T20:  [['1', '    –', 'Dawid Malan', 'ENGLAND', '841'], ['2', '    –', 'Babar Azam', 'PAKISTAN', '819'], ['3', '    1', 'Aaron Finch', 'AUSTRALIA', '733'], ['4', '    1', 'Virat Kohli', 'INDIA', '717'], ['5', '    2', 'Devon Conway', 'NEW ZEALAND', '700'], ['6', '    –', 'KL Rahul', 'INDIA', '699'], ['7', '    –', 'Mohammad Rizwan', 'PAKISTAN', '692'], ['8', '    4', 'Quinton de Kock', 'SOUTH AFRICA', '671'], ['9', '    –', 'Evin Lewis', 'WEST INDIES', '664'], ['10', '    1', 'Hazratullah Zazai', 'AFGHANISTAN', '636'], ['11', '    14', 'Aiden Markram', 'SOUTH AFRICA', '634'], ['12', '    4', 'Martin Guptill', 'NEW ZEALAND', '622'], ['13', '    3', 'Rassie van der Dussen', 'SOUTH AFRICA', '616'], ['14', '    1', 'Eoin Morgan', 'ENGLAND', '599'], ['15', '    9', 'Paul Stirling', 'IRELAND', '593'], ['16', '    2', 'Jason Roy', 'ENGLAND', '592'], ['17', '    1', 'Jos Buttler', 'ENGLAND', '590'], ['18', '    1', 'Jonny Bairstow', 'ENGLAND', '588'], ['19', '    1', 'George Munsey', 'SCOTLAND', '583'], ['20', '    10', 'Reeza Hendricks', 'SOUTH AFRICA', '579'], ['21', '    2', 'Rohit Sharma', 'INDIA', '577'], ['22', '    2', 'Rahmanullah Gurbaz', 'AFGHANISTAN', '576'], ['23', '    2', 'Mitchell Marsh', 'AUSTRALIA', '575'], ['24', '    5', 'Mohammad Naim', 'BANGLADESH', '574'], ['25', '    2', 'Glenn Maxwell', 'AUSTRALIA', '567'], ['27', '    1', 'Richie Berrington', 'SCOTLAND', '542'], ['28', '    13', 'Colin Munro', 'NEW ZEALAND', '535'], ['29', '    5', 'Mahmudullah', 'BANGLADESH', '527'], ['30', '    1', 'Shikhar Dhawan', 'INDIA', '526'], ['31', '    1', 'Mohammad Nabi', 'AFGHANISTAN', '523'], ['32', '    10', 'Tim Seifert', 'NEW ZEALAND', '518'], ['33', '    2', 'Shreyas Iyer', 'INDIA', '516'], ['34', '    3', 'Kyle Coetzer', 'SCOTLAND', '511'], ['35', '    4', 'Tony Ura', 'PAPUA NEW GUINEA', '503'], ['36', '    3', 'David Miller', 'SOUTH AFRICA', '503'], ['37', '    6', 'Kevin O Brien', 'IRELAND', '496'], ['38', '    11', 'Kusal Perera', 'SRI LANKA', '494'], ['39', '    1', 'Andrew Balbirnie', 'IRELAND', '494'], ['40', '    –', 'Ben Cooper', 'NETHERLANDS', '493'], ['41', '    15', 'Glenn Phillips', 'NEW ZEALAND', '492'], ['42', '    1', 'Najibullah Zadran', 'AFGHANISTAN', '492'], ['43', '    1', 'Max ODowd', 'NETHERLANDS', '491'], ['44', '    –', 'Tom Latham', 'NEW ZEALAND', '484'], ['45', '    –', 'Calum MacLeod', 'SCOTLAND', '483'], ['46', '    –', 'Jatinder Singh', 'OMAN', '482'], ['47', '    –', 'Fakhar Zaman', 'PAKISTAN', '481'], ['48', '    –', 'Nicholas Pooran', 'WEST INDIES', '481'], ['49', '    1', 'Suryakumar Yadav', 'INDIA', '477'], ['50', '    1', 'Matthew Cross', 'SCOTLAND', '474'], ['51', '    1', 'Asghar Afghan', 'AFGHANISTAN', '472'], ['52', '    16', 'Kane Williamson', 'NEW ZEALAND', '463'], ['53', '    1', 'Mohammad Usman', 'UNITED ARAB EMIRATES', '458'], ['54', '    1', 'Tim David', 'SINGAPORE', '457'], ['55', '    2', 'Shakib Al Hasan', 'BANGLADESH', '451'], ['56', '    1', 'Mohammad Hafeez', 'PAKISTAN', '446'], ['57', '    1', 'Kamran Khan', 'QATAR', '445'], ['58', '    1', 'Lendl Simmons', 'WEST INDIES', '443'], ['59', '    1', 'Kushal Bhurtel', 'NEPAL', '442'], ['60', '    16', 'Soumya Sarkar', 'BANGLADESH', '436'], ['61', '    –', 'Ravija Sandaruwan', 'KUWAIT', '435'], ['62', '    6', 'Liton Das', 'BANGLADESH', '435'], ['64', '    –', 'Gerhard Erasmus', 'NAMIBIA', '421'], ['65', '    2', 'Kieron Pollard', 'WEST INDIES', '417'], ['66', '    13', 'Finn Allen', 'NEW ZEALAND', '413'], ['67', '    2', 'Nizakat Khan', 'HONG KONG', '405'], ['68', '    2', 'D Arcy Short', 'AUSTRALIA', '404'], ['69', '    2', 'David Warner', 'AUSTRALIA', '401'], ['70', '    2', 'Shimron Hetmyer', 'WEST INDIES', '401'], ['72', '    9', 'Danushka Gunathilaka', 'SRI LANKA', '398'], ['73', '    –', 'Zeeshan Maqsood', 'OMAN', '398'], ['74', '    12', 'Collins Obuya', 'KENYA', '396'], ['75', '    9', 'Faf du Plessis', 'SOUTH AFRICA', '393'], ['76', '    12', 'Ryan Burl', 'ZIMBABWE', '391'], ['77', '    9', 'Temba Bavuma', 'SOUTH AFRICA' ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4884/1020397176.py in <module>
#      40 df1 = pd.DataFrame(ListOfTest,columns=["Position","Ranking","Player","Country","Rating"])
#      41 df1.to_excel(writer,sheet_name='Test',index=False)
# ---> 42 print(df)
#      43
#      44 df2 = pd.DataFrame(ListOfODI,columns=["Position","Ranking","Player","Country","Rating"])
#
# NameError: name 'df' is not defined

# %%
driverPath=r"C:\Users\merit\Desktop\Notes\Python\chromedriver_win32\chromedriver.exe"
driver=webdriver.Chrome(executable_path=driverPath)
driver.get("https://ai.fmcsa.dot.gov/hhg/Search.asp?ads=a&lan=en")
driver.maximize_window()

writer = pd.ExcelWriter('State.xlsx',engine = 'xlsxwriter')
for i in range (1,97):
    li=[]
    state=driver.find_element_by_xpath("//option[contains(text(),'Please select state')]//following::option["+str(i)+"]")
    state.click()
    d = state.text
    print(d,i)

    driver.find_element_by_xpath("//input[@name='Submit']").click()
    a = driver.find_elements_by_xpath("//tr[contains(@scope,'row')]")
    for j in a:
        li.append(j.text.split("  "))
    driver.back()
    df = pd.DataFrame(li,columns=["Name","Location","Type","Size"])
    df.to_excel(writer,sheet_name = d,index = False)

writer.save()
driver.close()

# %%
driverPath=r"C:\Users\merit\Desktop\Notes\Python\chromedriver_win32\chromedriver.exe"
driver=webdriver.Chrome(executable_path=driverPath)
driver.get("https://www.cricbuzz.com/cricket-team")
driver.maximize_window()

for i in range(1,38):
    with open(r"C:\Users\merit\Python Programs\Images\\"+str(i)+".png",'wb') as file:
        img = driver.find_element_by_xpath("//h1[contains(text(),'Cricket Teams')]//following::img["+str(i)+"]")
        file.write(img.screenshot_as_png)
driver.close()
